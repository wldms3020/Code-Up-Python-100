# %% [markdown]
# [6001](https://www.codeup.kr/problem.php?id=6001). print( )를 이용해 다음 단어를 출력하시오.
#
# Hello

# %%
print("Hello")

# %% [markdown]
# [6002](https://www.codeup.kr/problem.php?id=6002). 공백( )을 포함한 문장을 출력한다.
# 다음 문장을 출력해보자.
#
# Hello World
# (대소문자에 주의한다.)

# %%
print("Hello World")

# %% [markdown]
# [6003](https://www.codeup.kr/problem.php?id=6003). 줄을 바꿔 출력하는 출력문을 연습해보자.
# 다음과 같이 줄을 바꿔 출력해야 한다.
#
# Hello
#
# World
#
# (두 줄에 걸쳐 줄을 바꿔 출력)

# %%
print("Hello\nWorld")
# print("Hello")
# print("World")

# %% [markdown]
# [6004](https://www.codeup.kr/problem.php?id=6004). 작은 따옴표(')(single quotation mark)가 들어있는
# 출력문 연습을 해보자. 다음과 같은 문장을 출력해야 한다.
#
# 'Hello'

# %%
print("\'Hello\'")

# %% [markdown]
# [6005](https://www.codeup.kr/problem.php?id=6005). 큰따옴표(")(double quotation mark)가 포함된 출력문을 연습해보자. 다음과 같은 문장을 출력해야 한다.
#
# "Hello World"
# (단, 큰따옴표도 함께 출력한다.)

# %%
print("\"Hello World\"")

# %% [markdown]
# [6006](https://www.codeup.kr/problem.php?id=6006). 특수문자 출력에 도전하자!! 다음 문장을 출력해보자.
#
# "!@#$%^&*()'
# (단, 큰따옴표와 작은따옴표도 함께 출력한다.)

# %%
print("\"!@#$%^&*()\'")

# %% [markdown]
# [6007](https://www.codeup.kr/problem.php?id=6007). 윈도우 운영체제의 파일 경로를 출력하는 연습을 해보자.
#
# 파일 경로에는 특수문자들이 포함된다. 다음 경로를 출력하시오.
#
#  "C:\Download\\'hello'.py"
#  (단, 따옴표도 함께 출력한다.)

# %%
print("\"C:\Download\\'hello\'.py\"")

# %% [markdown]
# [6008](https://www.codeup.kr/problem.php?id=6008). 다음과 같은 python프로그램의 소스코드를 출력해보자.
#
# print("Hello\nWorld") (코드를 정확히 그대로 출력한다.)

# %%
print("print(\"Hello\\nWorld\")")

# %% [markdown]
# [6009](https://www.codeup.kr/problem.php?id=6009). 변수에 문자 1개를 저장한 후
# 변수에 저장되어 있는 문자를 그대로 출력해보자.

# %%
x = input()
print(x)

# %% [markdown]
# [6010](https://www.codeup.kr/problem.php?id=6010). 변수에 정수값을 저장한 후 정수로 변환하여 출력해보자.

# %%
x = int(input())
print(x)
