# %% [markdown]
# [6021](https://www.codeup.kr/problem.php?id=6021). 알파벳과 숫자로 이루어진 단어 1개가 입력된다. 입력받은 단어의 각 문자를 한 줄에 한 문자씩 분리해 출력한다.

# %%
a = input()
for x in list(a):
  print(x)

# %% [markdown]
# 입력
#
# Hello
#
# 출력
#
# H
#
# e
#
# l
#
# l
#
# o

# %% [markdown]
# [6022](https://www.codeup.kr/problem.php?id=6022). 6자리의 연월일(YYMMDD)을 입력받아 나누어 출력해보자. 년도(YY) 월(MM) 일(DD)을 공백으로 구분해 한 줄로 출력한다.

# %%
a = input()
print(a[0:2], a[2:4], a[4:6], end=' ')

# %% [markdown]
# 입력
#
# 200304
#
# 출력
#
# 20 03 04

# %% [markdown]
# [6023](https://www.codeup.kr/problem.php?id=6023). 시:분:초 형식으로 시간이 입력될 때 분만 출력해보자.

# %%
h, m, s = input().split(':')
print(m)

# %% [markdown]
# 입력
#
# 17:23:57
#
# 출력
#
# 23

# %% [markdown]
# [6024](https://www.codeup.kr/problem.php?id=6024). 알파벳 문자와 숫자로 이루어진 공백을 포함하는 단어 2개를 입력받아 순서대로 붙여 출력하는 프로그램을 작성해보자.

# %%
a, b = input().split(' ')
print(a, b, sep='')
# a, b = input().split()
# s = a + b
# print(s))

# %% [markdown]
# 입력
#
# hello world
#
# 출력
#
# helloworld

# %% [markdown]
# [6025](https://www.codeup.kr/problem.php?id=6025). 정수 2개를 입력받아 합을 출력하는 프로그램을 작성해보자. 2개의 정수가 공백으로 구분되어 입력된다.

# %%
a, b = input().split()
sum = int(a) + int(b)
print(sum)

# %% [markdown]
# 입력
#
# 123 -123
#
# 출력
#
# 0

# %% [markdown]
# [6026](https://www.codeup.kr/problem.php?id=6026). 실수 2개를 입력받아 합을 출력하는 프로그램을 작성해보자. 2개의 실수가 줄을 바꿔 입력된다.

# %%
a = float(input())
b = float(input())
sum = a + b
print(sum)

# %% [markdown]
# 입력
#
# 0.1
#
# 0.9
#
# 출력
#
# 1.0

# %% [markdown]
# [6027](https://www.codeup.kr/problem.php?id=6027). 10진수를 입력받아 16진수(hexadecimal)로 출력해보자. 16진수(소문자) 형태로 출력한다.

# %%
a = int(input())
print('%x'%a)
# hex(), %x, %X 출력 형태가 다름

# %% [markdown]
# 입력
#
# 255
#
# 출력
#
# ff

# %% [markdown]
# [6028](https://www.codeup.kr/problem.php?id=6028). 10진수를 입력받아 16진수(hexadecimal)로 출력해보자. 16진수(대문자) 형태로 출력한다.

# %%
a = int(input())
print('%X'%a)

# %% [markdown]
# 입력
#
# 255
#
# 출력
#
# FF

# %% [markdown]
# [6029](https://www.codeup.kr/problem.php?id=6029). 16진수를 입력받아 8진수(octal)로 출력해보자.

# %%
a = int(input(), 16) # int(변수, 진수)
print('%o'%a)

# %% [markdown]
# 입력
#
# f
#
# 출력
#
# 17

# %% [markdown]
# [6030](https://www.codeup.kr/problem.php?id=6030). 영문자 1개를 입력받아 10진수 유니코드(Unicode) 값으로 출력해보자.

# %%
a = ord(input()) # ord() : 문자 -> 아스키코드
print(a)
# ord() <-> chr() : 아스키코드 -> 문자

# %% [markdown]
# 입력
#
# A
#
# 출력
#
# 65
